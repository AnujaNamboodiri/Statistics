# %% [markdown]
# ## Topics covered in this notebook
#
# 1. Measuring skewness in a data
# 2. Karl Pearson coeff - positive/ negative skewed
# 3. Bowley's coeff
# 4. Kurtosis - Liptokurtic, mesokurtic, platykurtic rules
# 5. Probability in a frequency dist table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
