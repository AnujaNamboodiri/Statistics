# %% [markdown]
# ### <u> Question 1</u> : Explain descriptive and inferential statistics

# %% [markdown]
# #### Descriptive statistics
# * It deals with organizing and summarizing the data.
# * It includes measures of central tendency - *Mean, median, mode* and measures of dispersion - *Range, variance, standard devaition, quantile deviation*

# %% [markdown]
# #### Inferential statistics
#
# * It deals with collecting *sample* data, running experiements/tests on it for conclusions and inferences for the *population* data.

# %% [markdown]
# ### <u> Question 2</u> : Explain Population vs Sample

# %% [markdown]
# * Population is the entire dataset denoted by N. It is the entire group that you want to draw conclusions about
# * Sample is the subset of the population that is actually used for the analysis,that gives inferences about the population. It is usually denoted by n.

# %% [markdown]
# ### <u> Question 3</u> : Explain measures of central tendency

# %% [markdown]
# * Mean : Sum of observations / number of observations. It is the avergae of the observations
# * Median : Central value in the sorted list of observations. A good way to tackle outliers.
#     * Centre most observation in case of odd numbered list.
#     * Average of two center elements in case of even numbered list.
# * Mode : Most repeated value of an observation in a dataset. Element which has the maximum frequency.

# %% [markdown]
# ### <u>Question 4</u> : Difference between population mean and sample mean

# %% [markdown]
# * Sample mean is the average of the sample values picked from the population. The results resembles the population mean to a certain extent.
# * Sample Mean:
# ![image.png](attachment:image.png)
#
#
# * Population mean is the central tendency for the entire group.
# * Population Mean:
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### <u>Question 5</u> : Sample variance vs Population variance formula

# %% [markdown]
# * Population variance : ![image.png](attachment:image.png)
#
# * where,
#     * Σ is sum
#     * µ is Population mean
#     * xi is ith element from the population
#     * N is the population size
#
# * Sample variance : ![image.png](attachment:image-2.png)
#
# * where,
#     * x̄ is the sample mean
#     * xi is ith element from the population
#     * n is the sample size

# %% [markdown]
# ### <u> Question 6</u> : Why does sample variance use (n-1) and not n , like population variance uses N?

# %% [markdown]
# * In statistics, **Bessel's correction** is the use of n − 1 instead of n in the formula for the sample variance and sample standard deviation, where n is the number of observations in a sample.
# * This method corrects the bias in the estimation of the population variance.
#
# * Using n instead of (n-1) , there are chances that we underestimate the true population variance. Using (n-1) the error is reduced to an extent.
#
# Note:
# > When you have an entire population and calculate any parameter (like the population variance or population standard deviation), your results will be accurate. That’s because you have all the data about your population. However, when you work with a sample, you’ve only got a small fraction of the population to work with. Therefore, your answers aren’t going to be as accurate as those you would have got, if you had the entire set of data to work with.
#
# > In other words, sample calculations with n in the denominator are almost always going to be higher than calculations with n-1 in the denominator. When you subtract 1 from your sample size, it happens to turn out you’re making a fairly good adjustment for the deflated sum of squares figure as long as n isn’t huge

# %% [markdown]
# ### <u> Question 7</u> : What is standard deviation - formula and significance?

# %% [markdown]
# * Standard deviation signifies how far a data is away from the mean
# * Standard deviation formula is : ![image.png](attachment:image.png)
#
#
# * where,
#     * σ	=	population standard deviation
#     * N	=	the size of the population
#     * x_i	=	each value from the population
#     * µ	=	the population mean

# %% [markdown]
# ### <u>Question 8</u> : What is a variable, what are the different types and examples?

# %% [markdown]
# A variable is a property that can take up any value.
#
# > Types of variables
# 1. Quantitative
#     * Discrete Quantitative.
#         * Ex: No. of students in a class[30,52,67..]
#     * Continuous Quantitative.
#         * Ex: Weight of a person[80.2,72.6,53.1...]
# 2. Qualitative / Categorical
#     * Ex: Gender [Male/Female], Colours[Red,Blue,Green]

# %% [markdown]
# ### <u>Question 9</u>: What is percentile and how to calculate - "Percentile at value X" and "Value at percentile X" ?

# %% [markdown]
# **Percentile** : A percentile is a value below whch a certain percentage of observations lie.
# Ex: Dataset : [2,2,3,4,5,5,5,6,7,8,8,8,8,8,9,9,10,11,11,12]
#
# > Percentile rank of X = ( Number of values below X / n ) * 100
# 1. Percentile ranking of the value '10' = (16/20)*100 = 80%
#
# *"80% of the entire distribution is less than the value 10"*
#
# > Value @ Percentile  = ( Percentile / 100 ) * (n+1)
# 2. What value exists at the percentile ranking of 25% = (25 / 100) * (20+1) = 5.25 --> Index and not the value
#
# *'5.25' index position indicates avergae of 5th and 6th index i.e. avg(5,5) that is 5.
# So value at 25% percentile is 5*

# %% [markdown]
# ### <u> Question 10</u>:  What is Five Number Summary and how does it help in removing the outliers?

# %% [markdown]
# > Following are the five number/point summary of a dataset
# 1. Minimum
# 2. First Quartile Q1
# 3. Median / Second Quartile Q2
# 4. Third Quartile Q3
# 5. Maximum
#
# * For outlier detection
#     > Lower fence = Q1 - 1.5(IQR)
#
#     > Upper fence = Q3 + 1.5(IQR)
#     * Where,
#         * Q1 is 25 percentile and Q3 is 75 percentile
#         * IQR = Q3 - Q1
#         * Q3 = (75/100) * (n+1)
#         * Q1 = (25/100) * (n+1)
#
# Ex: Dataset : [1,2,2,2,3,3,4,5,5,5,6,6,6,6,7,8,8,9,27]
#
# 1. Q1 = (25/100) * (19+1) = 5 i.e. Value at 5th index
#     * Q1 = 3
# 2. Q3 = (75/100) * (19+1) = 15 i.e. Value at 15th index
#     * Q3 = 7
# 3. IQR = Q3 - Q1 = 7-3 = 4
# 4. Lower fence = 3 - 1.5(4) = -3
# 5. Upper fence = 7 + 1.5(4) = 13
#
# *Anything outside [-3,13] range is an outlier so '27' is an outlier.*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #

# %%
# Normally distributed random variable probablity
